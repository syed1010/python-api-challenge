# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import hvplot.pandas
import geoviews as gv
import geoviews.tile_sources as gts
import geoviews as gv
# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Import API key
geoapify_key = "5310e4b9ebd048beba99b1376a69cb63"

# Define the base URL for Geoapify API
base_url = "https://api.geoapify.com/v1/placeinfo"

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("/Users/syedshahid/python-api-challenge/WeatherPy/output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0  port-aux-francais -49.3500   70.2167    280.05        91
# 1        1            college  64.8569 -147.8028    281.12        74
# 2        2     ribeira grande  38.5167  -28.7000    290.80        91
# 3        3          iskateley  67.6803   53.1512    271.49        95
# 4        4          grytviken -54.2811  -36.5092    273.57        89
#
#    Cloudiness  Wind Speed Country        Date
# 0         100       17.82      TF  1715317837
# 1          75        3.13      US  1715317713
# 2          23        3.58      PT  1715317719
# 3         100       11.62      RU  1715317839
# 4         100        1.23      GS  1715317839

# %%
# Configure the map plot
gdf = gv.Points(city_data_df, ['Lng', 'Lat'], ['City', 'Humidity']).opts(
    size='Humidity', color='blue', width=700, height=500, tools=['hover'], global_extent=True
)

# Display the map
gdf
# Out:
# :Points   [Lng,Lat]   (City,Humidity)

# %%
# Narrow down cities that fit criteria
ideal_cities_df = city_data_df[
    (city_data_df['Max Temp'] < 27) & 
    (city_data_df['Max Temp'] > 21) & 
    (city_data_df['Wind Speed'] < 4.5) & 
    (city_data_df['Cloudiness'] == 0)
]

# Drop any rows with null values
ideal_cities_df = ideal_cities_df.dropna()

# Convert temperature from Kelvin to Celsius
city_data_df['Max Temp (C)'] = city_data_df['Max Temp'] - 273.15

# Display sample data with temperature in Celsius
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0  port-aux-francais -49.3500   70.2167    280.05        91
# 1        1            college  64.8569 -147.8028    281.12        74
# 2        2     ribeira grande  38.5167  -28.7000    290.80        91
# 3        3          iskateley  67.6803   53.1512    271.49        95
# 4        4          grytviken -54.2811  -36.5092    273.57        89
#
#    Cloudiness  Wind Speed Country        Date  Max Temp (C)
# 0         100       17.82      TF  1715317837          6.90
# 1          75        3.13      US  1715317713          7.97
# 2          23        3.58      PT  1715317719         17.65
# 3         100       11.62      RU  1715317839         -1.66
# 4         100        1.23      GS  1715317839          0.42

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df.head()
# Out:
#                 City Country      Lat       Lng  Humidity Hotel Name
# 0  port-aux-francais      TF -49.3500   70.2167        91
# 1            college      US  64.8569 -147.8028        74
# 2     ribeira grande      PT  38.5167  -28.7000        91
# 3          iskateley      RU  67.6803   53.1512        95
# 4          grytviken      GS -54.2811  -36.5092        89

# %%
# Set parameters to search for a hotel
radius = 10000  # 10,000 meters
params = {
    "filter": "lodging",
    "limit": 1,
    "radius": radius,
    "sort": "distance",
    "apiKey": geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from the DataFrame
    lat = row['Lat']
    lng = row['Lng']
    
    # Add latitude and longitude parameters to the params dictionary
    params["lat"] = lat
    params["lon"] = lng
    
    # Make an API request using the params dictionary
    response = requests.get(base_url, params=params).json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_name = response['features'][0]['properties']['name']
        hotel_df.loc[index, "Hotel Name"] = hotel_name
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# port-aux-francais - nearest hotel: No hotel found
# college - nearest hotel: No hotel found
# ribeira grande - nearest hotel: No hotel found
# iskateley - nearest hotel: No hotel found
# grytviken - nearest hotel: No hotel found
# isafjordur - nearest hotel: No hotel found
# kupang - nearest hotel: No hotel found
# kodiak - nearest hotel: No hotel found
# vanimo - nearest hotel: No hotel found
# puerto natales - nearest hotel: No hotel found
# invercargill - nearest hotel: No hotel found
# iqaluit - nearest hotel: No hotel found
# lupiro - nearest hotel: No hotel found
# keflavik - nearest hotel: No hotel found
# bethel - nearest hotel: No hotel found
# portland - nearest hotel: No hotel found
# albany - nearest hotel: No hotel found
# selfoss - nearest hotel: No hotel found
# machico - nearest hotel: No hotel found
# xining - nearest hotel: No hotel found
# hilo - nearest hotel: No hotel found
# adamstown - nearest hotel: No hotel found
# ...

# %%
# Configure the map plot
world_map = gv.tile_sources.CartoEco().opts(width=800, height=500)

# Create points representing cities with hotel names and countries as hover information
points = gv.Points(hotel_df, ['Lng', 'Lat'], ['City', 'Hotel Name', 'Country'])

# Overlay the points on the world map
hotel_map = world_map * points.opts(tools=['hover'])

# Display the map
hotel_map
