# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
from scipy.stats import linregress

# Import the OpenWeatherMap API key
weather_api_key = "803fbd5e4e89b023bc38d8cac4fe6bbe"

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# Create output directory if it doesn't exist
output_dir = "output_data"
os.makedirs(output_dir, exist_ok=True)

# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")

# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?q={city}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
print(city_data_df.count())

# Display sample data
print(city_data_df.head())

# Export the City_Data into a csv
city_data_df.to_csv(os.path.join(output_dir, "cities.csv"), index_label="City_ID")

# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (01/01/20)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig(os.path.join(output_dir, "Latitude_vs_Max_Temperature.png"))

# Show plot
plt.show()

# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (01/01/20)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig(os.path.join(output_dir, "Latitude_vs_Humidity.png"))

# Show plot
plt.show()

# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (01/01/20)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig(os.path.join(output_dir, "Latitude_vs_Cloudiness.png"))

# Show plot
plt.show()

# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (01/01/20)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig(os.path.join(output_dir, "Latitude_vs_Wind_Speed.png"))

# Show plot
plt.show()

# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    plt.title(f'Linear Regression on {title}')
    print(f"The r-squared is: {rvalue}")
    plt.show()

# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Northern Hemisphere - Temperature vs. Latitude Linear Regression
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], 'Max Temp',(6,30))

# Southern Hemisphere - Temperature vs. Latitude Linear Regression
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"], 'Max Temp',(-50,90))

# Northern Hemisphere - Humidity vs. Latitude Linear Regression
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], 'Humidity',(40,10))

# Southern Hemisphere - Humidity vs. Latitude Linear Regression
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], 'Humidity',(-50,15))

# Northern Hemisphere - Cloudiness vs. Latitude Linear Regression
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], 'Cloudiness',(40,10))

# Southern Hemisphere - Cloudiness vs. Latitude Linear Regression
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], 'Cloudiness',(-50,60))

# Northern Hemisphere - Wind Speed vs. Latitude Linear Regression
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], 'Wind Speed',(40,25))

# Southern Hemisphere - Wind Speed vs. Latitude Linear Regression
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], 'Wind Speed',(-50,20))
# Out:
# Number of cities in the list: 628
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | edinburgh of the seven seas
# Processing Record 2 of Set 1 | margaret river
# Processing Record 3 of Set 1 | tiksi
# Processing Record 4 of Set 1 | invercargill
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | dabakala
# Processing Record 7 of Set 1 | aripuana
# Processing Record 8 of Set 1 | severo-yeniseyskiy
# Processing Record 9 of Set 1 | samtse
# Processing Record 10 of Set 1 | kulia village
# City not found. Skipping...
# Processing Record 11 of Set 1 | vadso
# Processing Record 12 of Set 1 | adamstown
# Processing Record 13 of Set 1 | papatowai
# Processing Record 14 of Set 1 | gambiran satu
# Processing Record 15 of Set 1 | isle of bute
# City not found. Skipping...
# Processing Record 16 of Set 1 | keflavik
# Processing Record 17 of Set 1 | keyser
# Processing Record 18 of Set 1 | ponta delgada
# Processing Record 19 of Set 1 | college
# Processing Record 20 of Set 1 | hutchinson
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | nolinsk
# Processing Record 23 of Set 1 | tolanaro
# Processing Record 24 of Set 1 | utrik
# Processing Record 25 of Set 1 | west island
# Processing Record 26 of Set 1 | waitangi
# Processing Record 27 of Set 1 | grytviken
# Processing Record 28 of Set 1 | colonia
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | flin flon
# Processing Record 31 of Set 1 | palmer
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | tamanrasset
# Processing Record 34 of Set 1 | port-aux-francais
# Processing Record 35 of Set 1 | bethel
# Processing Record 36 of Set 1 | laghouat
# Processing Record 37 of Set 1 | kyshtovka
# Processing Record 38 of Set 1 | yunak
# Processing Record 39 of Set 1 | camarinas
# Processing Record 40 of Set 1 | plattsburgh
# Processing Record 41 of Set 1 | cooper's town
# Processing Record 42 of Set 1 | aitape
# Processing Record 43 of Set 1 | nyurba
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | iqaluit
# Processing Record 46 of Set 1 | macapa
# Processing Record 47 of Set 1 | olonkinbyen
# Processing Record 48 of Set 1 | shalqar
# Processing Record 49 of Set 1 | thompson
# Processing Record 50 of Set 1 | kodiak
# Processing Record 0 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 1 of Set 2 | tazovsky
# Processing Record 2 of Set 2 | blackmans bay
# Processing Record 3 of Set 2 | pasargad
# City not found. Skipping...
# Processing Record 4 of Set 2 | zheshart
# Processing Record 5 of Set 2 | garachico
# Processing Record 6 of Set 2 | zyryanskoye
# Processing Record 7 of Set 2 | mossendjo
# Processing Record 8 of Set 2 | prince rupert
# Processing Record 9 of Set 2 | crane
# Processing Record 10 of Set 2 | port mathurin
# Processing Record 11 of Set 2 | puerto baquerizo moreno
# Processing Record 12 of Set 2 | akjoujt
# Processing Record 13 of Set 2 | tinde
# Processing Record 14 of Set 2 | lorengau
# Processing Record 15 of Set 2 | gros islet
# Processing Record 16 of Set 2 | ulladulla
# Processing Record 17 of Set 2 | zavetnoye
# Processing Record 18 of Set 2 | chonchi
# Processing Record 19 of Set 2 | lihue
# Processing Record 20 of Set 2 | kralendijk
# Processing Record 21 of Set 2 | la passe
# Processing Record 22 of Set 2 | aasiaat
# Processing Record 23 of Set 2 | port alfred
# Processing Record 24 of Set 2 | tabou
# Processing Record 25 of Set 2 | puerto natales
# Processing Record 26 of Set 2 | ubinskoye
# Processing Record 27 of Set 2 | samsun
# Processing Record 28 of Set 2 | longyearbyen
# Processing Record 29 of Set 2 | trairi
# Processing Record 30 of Set 2 | cargados carajos
# City not found. Skipping...
# Processing Record 31 of Set 2 | jamestown
# Processing Record 32 of Set 2 | lompoc
# Processing Record 33 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 34 of Set 2 | kingston
# Processing Record 35 of Set 2 | hawaiian paradise park
# Processing Record 36 of Set 2 | partizansk
# Processing Record 37 of Set 2 | yreka
# Processing Record 38 of Set 2 | carutapera
# Processing Record 39 of Set 2 | ilulissat
# Processing Record 40 of Set 2 | patterson
# Processing Record 41 of Set 2 | klyuchi
# Processing Record 42 of Set 2 | pyt-yakh
# Processing Record 43 of Set 2 | mastic beach
# Processing Record 44 of Set 2 | icara
# Processing Record 45 of Set 2 | acapulco de juarez
# Processing Record 46 of Set 2 | beruniy
# Processing Record 47 of Set 2 | ancud
# Processing Record 48 of Set 2 | isafjordur
# Processing Record 49 of Set 2 | polyarnyy
# Processing Record 0 of Set 3 | asentamiento humano nicolas de pierola
# Processing Record 1 of Set 3 | castillos
# Processing Record 2 of Set 3 | sao jose da coroa grande
# Processing Record 3 of Set 3 | nova sintra
# Processing Record 4 of Set 3 | iskushuban
# Processing Record 5 of Set 3 | vsetin
# Processing Record 6 of Set 3 | papao
# Processing Record 7 of Set 3 | santa terezinha
# Processing Record 8 of Set 3 | tanjungtiram
# Processing Record 9 of Set 3 | enewetak
# Processing Record 10 of Set 3 | sungailiat
# Processing Record 11 of Set 3 | koratla
# Processing Record 12 of Set 3 | niafunke
# Processing Record 13 of Set 3 | elesbao veloso
# Processing Record 14 of Set 3 | uturoa
# Processing Record 15 of Set 3 | richards bay
# Processing Record 16 of Set 3 | puerto ayora
# Processing Record 17 of Set 3 | bangassou
# Processing Record 18 of Set 3 | rabah
# Processing Record 19 of Set 3 | sechura
# Processing Record 20 of Set 3 | new plymouth
# Processing Record 21 of Set 3 | tughyl
# Processing Record 22 of Set 3 | stanley
# Processing Record 23 of Set 3 | ribeira grande
# Processing Record 24 of Set 3 | taulaga
# Processing Record 25 of Set 3 | plettenberg bay
# Processing Record 26 of Set 3 | ylitornio
# Processing Record 27 of Set 3 | mogadishu
# Processing Record 28 of Set 3 | dudinka
# Processing Record 29 of Set 3 | inarajan village
# Processing Record 30 of Set 3 | lanzhou
# Processing Record 31 of Set 3 | kapuskasing
# Processing Record 32 of Set 3 | carnarvon
# Processing Record 33 of Set 3 | winnemucca
# Processing Record 34 of Set 3 | milford haven
# Processing Record 35 of Set 3 | ust-nera
# Processing Record 36 of Set 3 | yagry
# City not found. Skipping...
# Processing Record 37 of Set 3 | st. john's
# Processing Record 38 of Set 3 | yung shue wan
# Processing Record 39 of Set 3 | sorong
# Processing Record 40 of Set 3 | wellawaya
# Processing Record 41 of Set 3 | phan rang-thap cham
# Processing Record 42 of Set 3 | oranjemund
# Processing Record 43 of Set 3 | nemuro
# Processing Record 44 of Set 3 | punta arenas
# Processing Record 45 of Set 3 | nechi
# Processing Record 46 of Set 3 | comonfort
# Processing Record 47 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 48 of Set 3 | birzebbuga
# Processing Record 49 of Set 3 | fort bragg
# Processing Record 0 of Set 4 | kaohsiung
# Processing Record 1 of Set 4 | bilibino
# Processing Record 2 of Set 4 | san pedro pochutla
# Processing Record 3 of Set 4 | choa saidan shah
# Processing Record 4 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 5 of Set 4 | hermanus
# Processing Record 6 of Set 4 | rongelap
# Processing Record 7 of Set 4 | la sarre
# Processing Record 8 of Set 4 | salinopolis
# Processing Record 9 of Set 4 | tara
# Processing Record 10 of Set 4 | sievi
# Processing Record 11 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 12 of Set 4 | mo i rana
# Processing Record 13 of Set 4 | badger
# Processing Record 14 of Set 4 | labuan lombok
# City not found. Skipping...
# Processing Record 15 of Set 4 | mahibadhoo
# Processing Record 16 of Set 4 | dhuusamarreeb
# Processing Record 17 of Set 4 | talara
# Processing Record 18 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 4 | sisimiut
# Processing Record 20 of Set 4 | kitob
# Processing Record 21 of Set 4 | umba
# Processing Record 22 of Set 4 | qaqortoq
# Processing Record 23 of Set 4 | flying fish cove
# Processing Record 24 of Set 4 | candido de abreu
# Processing Record 25 of Set 4 | iskateley
# Processing Record 26 of Set 4 | mana
# Processing Record 27 of Set 4 | abong mbang
# Processing Record 28 of Set 4 | ceeldheer
# Processing Record 29 of Set 4 | manokwari
# Processing Record 30 of Set 4 | tilaran
# Processing Record 31 of Set 4 | manggar
# Processing Record 32 of Set 4 | mount gambier
# Processing Record 33 of Set 4 | kenai
# Processing Record 34 of Set 4 | sitka
# Processing Record 35 of Set 4 | karasuk
# Processing Record 36 of Set 4 | iquique
# Processing Record 37 of Set 4 | kargopol'
# Processing Record 38 of Set 4 | khandyga
# Processing Record 39 of Set 4 | benito garcia (el zorrillo)
# City not found. Skipping...
# Processing Record 40 of Set 4 | balabac
# Processing Record 41 of Set 4 | moroni
# Processing Record 42 of Set 4 | chandler
# Processing Record 43 of Set 4 | vilyuchinsk
# Processing Record 44 of Set 4 | port douglas
# Processing Record 45 of Set 4 | wytheville
# Processing Record 46 of Set 4 | holualoa
# Processing Record 47 of Set 4 | bardai
# Processing Record 48 of Set 4 | sukumo
# Processing Record 49 of Set 4 | georgetown
# Processing Record 0 of Set 5 | namibe
# Processing Record 1 of Set 5 | afaahiti
# Processing Record 2 of Set 5 | east end
# Processing Record 3 of Set 5 | whitehorse
# Processing Record 4 of Set 5 | hithadhoo
# Processing Record 5 of Set 5 | east london
# Processing Record 6 of Set 5 | vilyuysk
# Processing Record 7 of Set 5 | kiunga
# Processing Record 8 of Set 5 | wailua homesteads
# Processing Record 9 of Set 5 | hadibu
# Processing Record 10 of Set 5 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 11 of Set 5 | yanykurgan
# Processing Record 12 of Set 5 | road town
# Processing Record 13 of Set 5 | chipinge
# Processing Record 14 of Set 5 | vernon
# Processing Record 15 of Set 5 | talnakh
# Processing Record 16 of Set 5 | rio grande
# Processing Record 17 of Set 5 | shengli
# Processing Record 18 of Set 5 | vila velha
# Processing Record 19 of Set 5 | galliano
# Processing Record 20 of Set 5 | mawu
# Processing Record 21 of Set 5 | ephraim
# Processing Record 22 of Set 5 | kargil
# Processing Record 23 of Set 5 | chibougamau
# Processing Record 24 of Set 5 | la'ie
# Processing Record 25 of Set 5 | podporozh'ye
# Processing Record 26 of Set 5 | bayanaul
# Processing Record 27 of Set 5 | fria
# Processing Record 28 of Set 5 | dunedin
# Processing Record 29 of Set 5 | qaisumah
# Processing Record 30 of Set 5 | matam
# Processing Record 31 of Set 5 | weno
# Processing Record 32 of Set 5 | suoyarvi
# Processing Record 33 of Set 5 | mejit
# Processing Record 34 of Set 5 | alta
# Processing Record 35 of Set 5 | bakchar
# Processing Record 36 of Set 5 | hasaki
# Processing Record 37 of Set 5 | mount pearl
# Processing Record 38 of Set 5 | luderitz
# Processing Record 39 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 40 of Set 5 | vorgashor
# Processing Record 41 of Set 5 | kuta
# Processing Record 42 of Set 5 | williams lake
# Processing Record 43 of Set 5 | bandrele
# Processing Record 44 of Set 5 | arraial do cabo
# Processing Record 45 of Set 5 | tura
# Processing Record 46 of Set 5 | machico
# Processing Record 47 of Set 5 | huicheng
# Processing Record 48 of Set 5 | ta`u
# Processing Record 49 of Set 5 | elizabeth city
# Processing Record 0 of Set 6 | barranca
# Processing Record 1 of Set 6 | greymouth
# Processing Record 2 of Set 6 | port lincoln
# Processing Record 3 of Set 6 | taman rajawali
# City not found. Skipping...
# Processing Record 4 of Set 6 | nsanje
# Processing Record 5 of Set 6 | kailua-kona
# Processing Record 6 of Set 6 | ocean city
# Processing Record 7 of Set 6 | kerikeri
# Processing Record 8 of Set 6 | chui
# Processing Record 9 of Set 6 | morondava
# Processing Record 10 of Set 6 | as sulayyil
# Processing Record 11 of Set 6 | saint-philippe
# Processing Record 12 of Set 6 | leo
# Processing Record 13 of Set 6 | al qitena
# Processing Record 14 of Set 6 | aykhal
# Processing Record 15 of Set 6 | salaga
# Processing Record 16 of Set 6 | manavalakurichi
# Processing Record 17 of Set 6 | mansa konko
# Processing Record 18 of Set 6 | strezhevoy
# Processing Record 19 of Set 6 | beshariq
# Processing Record 20 of Set 6 | old forge
# Processing Record 21 of Set 6 | atafu village
# Processing Record 22 of Set 6 | lebu
# Processing Record 23 of Set 6 | bonthe
# Processing Record 24 of Set 6 | bodri
# Processing Record 25 of Set 6 | kristiansund
# Processing Record 26 of Set 6 | alofi
# Processing Record 27 of Set 6 | fortuna
# Processing Record 28 of Set 6 | kisangani
# Processing Record 29 of Set 6 | xilin hot
# Processing Record 30 of Set 6 | redencao
# Processing Record 31 of Set 6 | sierra grande
# Processing Record 32 of Set 6 | sola
# Processing Record 33 of Set 6 | susuman
# Processing Record 34 of Set 6 | raja
# Processing Record 35 of Set 6 | constantia
# Processing Record 36 of Set 6 | san clemente del tuyu
# Processing Record 37 of Set 6 | lembar
# City not found. Skipping...
# Processing Record 38 of Set 6 | paranhos
# Processing Record 39 of Set 6 | chul'man
# Processing Record 40 of Set 6 | akureyri
# Processing Record 41 of Set 6 | puerto madryn
# Processing Record 42 of Set 6 | zaragoza
# Processing Record 43 of Set 6 | tera
# Processing Record 44 of Set 6 | palma sola
# Processing Record 45 of Set 6 | asau
# Processing Record 46 of Set 6 | marataizes
# Processing Record 47 of Set 6 | axim
# Processing Record 48 of Set 6 | kocarli
# Processing Record 49 of Set 6 | nantucket
# Processing Record 0 of Set 7 | alakurtti
# Processing Record 1 of Set 7 | al hayy
# Processing Record 2 of Set 7 | vila franca do campo
# Processing Record 3 of Set 7 | san patricio
# Processing Record 4 of Set 7 | newman
# Processing Record 5 of Set 7 | turbat
# Processing Record 6 of Set 7 | christchurch
# Processing Record 7 of Set 7 | boa vista
# Processing Record 8 of Set 7 | avarua
# Processing Record 9 of Set 7 | wewak
# Processing Record 10 of Set 7 | gaspe
# Processing Record 11 of Set 7 | wonsan
# Processing Record 12 of Set 7 | praia
# Processing Record 13 of Set 7 | ivdel'
# Processing Record 14 of Set 7 | seogwipo
# City not found. Skipping...
# Processing Record 15 of Set 7 | page
# Processing Record 16 of Set 7 | bhandara
# Processing Record 17 of Set 7 | shatsk
# Processing Record 18 of Set 7 | burang
# Processing Record 19 of Set 7 | port moresby
# Processing Record 20 of Set 7 | boende
# Processing Record 21 of Set 7 | gantiadi
# Processing Record 22 of Set 7 | xique xique
# Processing Record 23 of Set 7 | thunder bay
# Processing Record 24 of Set 7 | manadhoo
# Processing Record 25 of Set 7 | cill airne
# Processing Record 26 of Set 7 | mburucuya
# Processing Record 27 of Set 7 | hamilton
# Processing Record 28 of Set 7 | ostersund
# Processing Record 29 of Set 7 | gornopravdinsk
# Processing Record 30 of Set 7 | illizi
# Processing Record 31 of Set 7 | nogliki
# Processing Record 32 of Set 7 | zahedan
# Processing Record 33 of Set 7 | dolores
# Processing Record 34 of Set 7 | poronaysk
# Processing Record 35 of Set 7 | beni saf
# Processing Record 36 of Set 7 | cannonvale
# Processing Record 37 of Set 7 | ellsworth
# Processing Record 38 of Set 7 | pisco
# Processing Record 39 of Set 7 | banda aceh
# Processing Record 40 of Set 7 | faya-largeau
# Processing Record 41 of Set 7 | saint joseph
# Processing Record 42 of Set 7 | fort-shevchenko
# Processing Record 43 of Set 7 | kavali
# Processing Record 44 of Set 7 | vorkuta
# Processing Record 45 of Set 7 | piti village
# Processing Record 46 of Set 7 | naryn
# Processing Record 47 of Set 7 | priob'ye
# Processing Record 48 of Set 7 | gallup
# Processing Record 49 of Set 7 | lodja
# Processing Record 0 of Set 8 | urzhar
# Processing Record 1 of Set 8 | kati
# Processing Record 2 of Set 8 | nar'yan-mar
# Processing Record 3 of Set 8 | bereznik
# Processing Record 4 of Set 8 | saudarkrokur
# Processing Record 5 of Set 8 | yigo village
# Processing Record 6 of Set 8 | gorontalo
# Processing Record 7 of Set 8 | quepos
# Processing Record 8 of Set 8 | midelt
# Processing Record 9 of Set 8 | touros
# Processing Record 10 of Set 8 | divnogorsk
# Processing Record 11 of Set 8 | comodoro rivadavia
# Processing Record 12 of Set 8 | cherpulassery
# Processing Record 13 of Set 8 | dali
# Processing Record 14 of Set 8 | chaman
# Processing Record 15 of Set 8 | fonte boa
# Processing Record 16 of Set 8 | itaituba
# Processing Record 17 of Set 8 | udachny
# Processing Record 18 of Set 8 | korla
# Processing Record 19 of Set 8 | ad dawadimi
# Processing Record 20 of Set 8 | wynyard
# Processing Record 21 of Set 8 | ar ram wa dahiyat al barid
# Processing Record 22 of Set 8 | suzhou
# Processing Record 23 of Set 8 | maughold
# Processing Record 24 of Set 8 | armacao de buzios
# Processing Record 25 of Set 8 | big rapids
# Processing Record 26 of Set 8 | happy valley-goose bay
# Processing Record 27 of Set 8 | puerto santa
# Processing Record 28 of Set 8 | sinabang
# Processing Record 29 of Set 8 | phalaborwa
# Processing Record 30 of Set 8 | radviliskis
# Processing Record 31 of Set 8 | onguday
# Processing Record 32 of Set 8 | pecos
# Processing Record 33 of Set 8 | mukharram al fawqani
# Processing Record 34 of Set 8 | sao vicente
# Processing Record 35 of Set 8 | beira
# Processing Record 36 of Set 8 | tqvarch'eli
# Processing Record 37 of Set 8 | usinsk
# Processing Record 38 of Set 8 | toliara
# Processing Record 39 of Set 8 | fort payne
# Processing Record 40 of Set 8 | saipan
# Processing Record 41 of Set 8 | hayma'
# City not found. Skipping...
# Processing Record 42 of Set 8 | nchelenge
# Processing Record 43 of Set 8 | ulsteinvik
# Processing Record 44 of Set 8 | salinas
# Processing Record 45 of Set 8 | coruripe
# Processing Record 46 of Set 8 | necochea
# Processing Record 47 of Set 8 | enoch
# Processing Record 48 of Set 8 | taskopru
# Processing Record 49 of Set 8 | kapa'a
# Processing Record 0 of Set 9 | lubang
# Processing Record 1 of Set 9 | padre paraiso
# Processing Record 2 of Set 9 | anadyr
# Processing Record 3 of Set 9 | prado
# Processing Record 4 of Set 9 | cambria
# Processing Record 5 of Set 9 | kananga
# Processing Record 6 of Set 9 | maydanshakhr
# Processing Record 7 of Set 9 | mbuji-mayi
# Processing Record 8 of Set 9 | borgarnes
# Processing Record 9 of Set 9 | veraval
# Processing Record 10 of Set 9 | hirara
# Processing Record 11 of Set 9 | emporia
# Processing Record 12 of Set 9 | yuzhno-kurilsk
# Processing Record 13 of Set 9 | alice springs
# Processing Record 14 of Set 9 | esquel
# Processing Record 15 of Set 9 | sikonge
# Processing Record 16 of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 17 of Set 9 | rikaze
# Processing Record 18 of Set 9 | filey
# Processing Record 19 of Set 9 | posse
# Processing Record 20 of Set 9 | mokhsogollokh
# Processing Record 21 of Set 9 | trebinje
# Processing Record 22 of Set 9 | phongsali
# Processing Record 23 of Set 9 | ballito
# Processing Record 24 of Set 9 | pitimbu
# Processing Record 25 of Set 9 | sao paulo de olivenca
# Processing Record 26 of Set 9 | urangan
# Processing Record 27 of Set 9 | ubari
# Processing Record 28 of Set 9 | tsiombe
# Processing Record 29 of Set 9 | puerto deseado
# Processing Record 30 of Set 9 | tarawa
# Processing Record 31 of Set 9 | kemijarvi
# Processing Record 32 of Set 9 | blackwater
# Processing Record 33 of Set 9 | ilabaya
# Processing Record 34 of Set 9 | aspen
# Processing Record 35 of Set 9 | dourados
# Processing Record 36 of Set 9 | nehe
# Processing Record 37 of Set 9 | nykobing sjaelland
# Processing Record 38 of Set 9 | lerwick
# Processing Record 39 of Set 9 | bela vista
# Processing Record 40 of Set 9 | bay roberts
# Processing Record 41 of Set 9 | trapani
# Processing Record 42 of Set 9 | saint-joseph
# Processing Record 43 of Set 9 | peterhead
# Processing Record 44 of Set 9 | salumbar
# Processing Record 45 of Set 9 | murghob
# Processing Record 46 of Set 9 | amga
# Processing Record 47 of Set 9 | nambucca heads
# Processing Record 48 of Set 9 | muli
# Processing Record 49 of Set 9 | salug
# Processing Record 0 of Set 10 | porto de moz
# Processing Record 1 of Set 10 | antigonish
# Processing Record 2 of Set 10 | saint-paul
# Processing Record 3 of Set 10 | bei'an
# Processing Record 4 of Set 10 | san pedro
# Processing Record 5 of Set 10 | hammerfest
# Processing Record 6 of Set 10 | qamdo
# Processing Record 7 of Set 10 | novotroitsk
# Processing Record 8 of Set 10 | toga village
# City not found. Skipping...
# Processing Record 9 of Set 10 | cockburn town
# Processing Record 10 of Set 10 | jayapura
# Processing Record 11 of Set 10 | novoukrayinka
# Processing Record 12 of Set 10 | tofol
# Processing Record 13 of Set 10 | kudat
# Processing Record 14 of Set 10 | the pas
# Processing Record 15 of Set 10 | yanaul
# Processing Record 16 of Set 10 | wismar
# Processing Record 17 of Set 10 | harper
# Processing Record 18 of Set 10 | tranovaho
# City not found. Skipping...
# Processing Record 19 of Set 10 | kem'
# Processing Record 20 of Set 10 | nagyatad
# Processing Record 21 of Set 10 | leava
# Processing Record 22 of Set 10 | tumayr
# Processing Record 23 of Set 10 | kodinsk
# Processing Record 24 of Set 10 | san antonio de pale
# Processing Record 25 of Set 10 | gadzhiyevo
# Processing Record 26 of Set 10 | kathmandu
# Processing Record 27 of Set 10 | tarashcha
# Processing Record 28 of Set 10 | haiku-pauwela
# Processing Record 29 of Set 10 | cabo san lucas
# Processing Record 30 of Set 10 | molina
# Processing Record 31 of Set 10 | goshen
# Processing Record 32 of Set 10 | rupea
# Processing Record 33 of Set 10 | allapalli
# Processing Record 34 of Set 10 | bir el ater
# Processing Record 35 of Set 10 | dryden
# Processing Record 36 of Set 10 | bom jesus
# Processing Record 37 of Set 10 | narasannapeta
# Processing Record 38 of Set 10 | mitchell
# Processing Record 39 of Set 10 | horsham
# Processing Record 40 of Set 10 | isangel
# Processing Record 41 of Set 10 | reggane
# Processing Record 42 of Set 10 | san fernando
# Processing Record 43 of Set 10 | chela
# Processing Record 44 of Set 10 | tazacorte
# Processing Record 45 of Set 10 | majene
# Processing Record 46 of Set 10 | san luis de la loma
# Processing Record 47 of Set 10 | port blair
# Processing Record 48 of Set 10 | restrepo
# Processing Record 49 of Set 10 | singaparna
# Processing Record 0 of Set 11 | ghormach
# Processing Record 1 of Set 11 | farsan
# Processing Record 2 of Set 11 | aldinga beach
# Processing Record 3 of Set 11 | tabas
# Processing Record 4 of Set 11 | sao felix do xingu
# Processing Record 5 of Set 11 | meiktila
# Processing Record 6 of Set 11 | awjilah
# Processing Record 7 of Set 11 | kuanda
# Processing Record 8 of Set 11 | hauterive
# Processing Record 9 of Set 11 | ugoofaaru
# Processing Record 10 of Set 11 | la huacana
# Processing Record 11 of Set 11 | al ghayzah
# Processing Record 12 of Set 11 | rantepao
# Processing Record 13 of Set 11 | sayat
# Processing Record 14 of Set 11 | ringkobing
# Processing Record 15 of Set 11 | magadan
# Processing Record 16 of Set 11 | talcahuano
# Processing Record 17 of Set 11 | san jose village
# City not found. Skipping...
# Processing Record 18 of Set 11 | leh
# Processing Record 19 of Set 11 | moranbah
# Processing Record 20 of Set 11 | nkurenkuru
# City not found. Skipping...
# Processing Record 21 of Set 11 | xining
# Processing Record 22 of Set 11 | ouani
# Processing Record 23 of Set 11 | betare oya
# Processing Record 24 of Set 11 | borazjan
# Processing Record 25 of Set 11 | preobrazheniye
# Processing Record 26 of Set 11 | guerrero
# Processing Record 27 of Set 11 | gimbi
# Processing Record 28 of Set 11 | qo'rg'ontepa
# Processing Record 29 of Set 11 | wattegama
# Processing Record 30 of Set 11 | queenstown
# Processing Record 31 of Set 11 | chulym
# Processing Record 32 of Set 11 | ust-tsilma
# Processing Record 33 of Set 11 | wawa
# Processing Record 34 of Set 11 | balqash
# Processing Record 35 of Set 11 | labytnangi
# Processing Record 36 of Set 11 | tanjung selor
# City not found. Skipping...
# Processing Record 37 of Set 11 | secunderabad
# Processing Record 38 of Set 11 | arti
# Processing Record 39 of Set 11 | kuala belait
# Processing Record 40 of Set 11 | alenquer
# Processing Record 41 of Set 11 | vingt cinq
# City not found. Skipping...
# Processing Record 42 of Set 11 | amahai
# Processing Record 43 of Set 11 | oppdal
# Processing Record 44 of Set 11 | maintirano
# Processing Record 45 of Set 11 | datong
# Processing Record 46 of Set 11 | nikolayevsk-on-amure
# Processing Record 47 of Set 11 | taltal
# Processing Record 48 of Set 11 | dazhou
# Processing Record 49 of Set 11 | robertsport
# Processing Record 0 of Set 12 | piterka
# Processing Record 1 of Set 12 | general acha
# Processing Record 2 of Set 12 | bushland beach
# City not found. Skipping...
# Processing Record 3 of Set 12 | starobin
# Processing Record 4 of Set 12 | yatou
# Processing Record 5 of Set 12 | ventspils
# Processing Record 6 of Set 12 | celestun
# Processing Record 7 of Set 12 | ipilan
# Processing Record 8 of Set 12 | springbok
# Processing Record 9 of Set 12 | omegna
# Processing Record 10 of Set 12 | fort mcmurray
# Processing Record 11 of Set 12 | gulf breeze
# Processing Record 12 of Set 12 | warmbad
# Processing Record 13 of Set 12 | kataragama
# City not found. Skipping...
# Processing Record 14 of Set 12 | cuatro cienegas de carranza
# Processing Record 15 of Set 12 | pindushi
# Processing Record 16 of Set 12 | priozersk
# Processing Record 17 of Set 12 | kamina
# Processing Record 18 of Set 12 | anzio
# Processing Record 19 of Set 12 | newquay
# Processing Record 20 of Set 12 | mundri
# Processing Record 21 of Set 12 | melfort
# Processing Record 22 of Set 12 | handlova
# Processing Record 23 of Set 12 | barrouallie
# Processing Record 24 of Set 12 | borogontsy
# Processing Record 25 of Set 12 | howrah
# Processing Record 26 of Set 12 | jieshi
# Processing Record 27 of Set 12 | sabi
# Processing Record 28 of Set 12 | atar
# Processing Record 29 of Set 12 | mbekenyera
# Processing Record 30 of Set 12 | san sebastian de la gomera
# Processing Record 31 of Set 12 | ponorogo
# Processing Record 32 of Set 12 | sittwe
# Processing Record 33 of Set 12 | balotra
# Processing Record 34 of Set 12 | gobabis
# Processing Record 35 of Set 12 | payakumbuh
# Processing Record 36 of Set 12 | adigrat
# Processing Record 37 of Set 12 | kas
# Processing Record 38 of Set 12 | north bend
# Processing Record 39 of Set 12 | laguna
# Processing Record 40 of Set 12 | santo antonio do ica
# Processing Record 41 of Set 12 | borgo valsugana
# Processing Record 42 of Set 12 | santa cruz
# Processing Record 43 of Set 12 | san borja
# Processing Record 44 of Set 12 | champerico
# Processing Record 45 of Set 12 | ebaye
# Processing Record 46 of Set 12 | palmas de monte alto
# Processing Record 47 of Set 12 | shimoda
# Processing Record 48 of Set 12 | zilair
# Processing Record 49 of Set 12 | lagos
# Processing Record 0 of Set 13 | lata
# Processing Record 1 of Set 13 | tomatlan
# Processing Record 2 of Set 13 | redkino
# Processing Record 3 of Set 13 | laurel
# Processing Record 4 of Set 13 | arenapolis
# Processing Record 5 of Set 13 | patong
# Processing Record 6 of Set 13 | hoxtolgay
# City not found. Skipping...
# Processing Record 7 of Set 13 | kihurio
# Processing Record 8 of Set 13 | ketchikan
# Processing Record 9 of Set 13 | trincomalee
# Processing Record 10 of Set 13 | yinchuan
# Processing Record 11 of Set 13 | santana
# Processing Record 12 of Set 13 | nieuw amsterdam
# Processing Record 13 of Set 13 | tangalle
# Processing Record 14 of Set 13 | nagqu
# Processing Record 15 of Set 13 | berdigestyakh
# Processing Record 16 of Set 13 | guerrero negro
# Processing Record 17 of Set 13 | yeppoon
# Processing Record 18 of Set 13 | koneurgench
# City not found. Skipping...
# Processing Record 19 of Set 13 | balykshi
# Processing Record 20 of Set 13 | kasaragod
# Processing Record 21 of Set 13 | tayshet
# Processing Record 22 of Set 13 | dholka
# Processing Record 23 of Set 13 | belmonte
# Processing Record 24 of Set 13 | manta
# Processing Record 25 of Set 13 | darovskoy
# Processing Record 26 of Set 13 | coquimbo
# Processing Record 27 of Set 13 | codrington
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# City          599
# Lat           599
# Lng           599
# Max Temp      599
# Humidity      599
# Cloudiness    599
# Wind Speed    599
# Country       599
# Date          599
# dtype: int64
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0  edinburgh of the seven seas -37.0676  -12.3116    289.74        92
# 1               margaret river -33.9500  115.0667    297.17        38
# 2                        tiksi  71.6872  128.8694    273.16        93
# 3                 invercargill -46.4000  168.3500    279.83        78
# 4               port elizabeth -33.9180   25.5701    292.09        77
#
#    Cloudiness  Wind Speed Country        Date
# 0         100       14.16      SH  1715149489
# 1          84        1.87      AU  1715149258
# 2         100        4.56      RU  1715149490
# 3          83        3.24      NZ  1715149288
# 4           0        5.14      ZA  1715149490
# The r-squared is: -0.8542359332763071
# The r-squared is: 0.7922460923142546
# The r-squared is: 0.151911232337595
# The r-squared is: 0.10338878862341369
# The r-squared is: 0.08307662908120866
# The r-squared is: 0.13015606842850183
# The r-squared is: 0.10057758423145086
# The r-squared is: -0.19981747067646924
